# %% [markdown]
# #Megha (CSE AI-2, 11001172024) Assignment-1

# %%
length = float(input("Enter the length of rectangle: "))
width = float(input("Enter the breafth of the rectangle: "))
1
Area = length*width

print("Area of Rectangle: ",Area,"square.unit")
# Out:
# Enter the length of rectangle: 15
# Enter the breafth of the rectangle: 2
# Area of Rectangle:  30.0 square.unit

# %%
P = float(input("Enter Principal Amount: "))
R = float(input("Enter Rate of Interest: "))
T = float(input("Enter Time (years): "))

SI = (P * R * T) / 100

print("Simple Interest =", SI)
# Out:
# Enter Principal Amount: 5000
# Enter Rate of Interest: 18
# Enter Time (years): 3
# Simple Interest = 2700.0

# %%
Celcius = float(input("Enter the temprtaure in celcius:"))
Fahrenheit = (Celcius * 9/5) + 32
print("Temprature in Farhenheit:",Fahrenheit)
# Out:
# Enter the temprtaure in celcius:23.3
# Temprature in Farhenheit: 73.94

# %%
num1 = float(input("Enter first number:"))
num2 = float(input("Enter second number:"))
num3 = float(input("Enter third number:"))

avg = (num1+num2+num3)/3
print("Average of 3 number:",avg)
# Out:
# Enter first number:34.5
# Enter second number:34
# Enter third number:78.3
# Average of 3 number: 48.93333333333334

# %%
num = float(input("Enter a Number:"))

Square = num  ** 2
Cube = num ** 3

print("Square of the given number:",Square)
print("Cube of the given number:",Cube)
# Out:
# Enter a Number:2
# Square of the given number: 4.0
# Cube of the given number: 8.0

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a,b=b,a

print("After swapping:\nfirst number =",a)
print("second number =",b)
# Out:
# Enter first number: 34
# Enter second number: 23
# After swapping:
# first number = 23
# second number = 34

# %%
#Taking Student Detail:
name = input("Enter student name:")
roll_no = int(input("Enter roll number of the student"))

# Collect the subjects:
s1 = float(input("Enter the marks of subject 1:"))
s2 = float(input("Enter the marks of subject 2:"))
s3 = float(input("Enter the marks of subject 3:"))
s4 = float(input("Enter the marks of subject 4:"))
s5 = float(input("Enter the marks of subject 5:"))

#calculate the total of Marks and precentage:
Total = s1+s2+s3+s4+s5
Percentage = (Total / 500) * 100

#Printing detail:
print("Total Marks",Total)
print("Precenetage",Percentage)
# Out:
# Enter student name:Megha
# Enter roll number of the student110
# Enter the marks of subject 1:98
# Enter the marks of subject 2:99
# Enter the marks of subject 3:97
# Enter the marks of subject 4:96
# Enter the marks of subject 5:96
# Total Marks 486.0
# Precenetage 97.2
